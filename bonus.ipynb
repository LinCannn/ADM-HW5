# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/ADM-HW5')

# %%
import sys
sys.path.append('/content/drive/MyDrive/ADM-HW5/auxiliary_files')

# %%
# !pip install pyspark==3.1.3
# Out:
# Requirement already satisfied: pyspark==3.1.3 in /usr/local/lib/python3.10/dist-packages (3.1.3)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.10/dist-packages (from pyspark==3.1.3) (0.10.9)

# %%
# !wget https://repos.spark-packages.org/graphframes/graphframes/0.8.3-spark 3.1.3-s_2.12/graphframes-0.8.3-spark3.5-s_2.12.jar -P /content/
# Out:
# --2024-12-23 05:52:56--  https://repos.spark-packages.org/graphframes/graphframes/0.8.3-spark
# Resolving repos.spark-packages.org (repos.spark-packages.org)... 18.160.143.35, 18.160.143.11, 18.160.143.50, ...
# Connecting to repos.spark-packages.org (repos.spark-packages.org)|18.160.143.35|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-12-23 05:52:57 ERROR 404: Not Found.
#
# --2024-12-23 05:52:57--  http://3.1.3-s_2.12/graphframes-0.8.3-spark3.5-s_2.12.jar
# Resolving 3.1.3-s_2.12 (3.1.3-s_2.12)... failed: Name or service not known.
# wget: unable to resolve host address ‘3.1.3-s_2.12’

# %%
pip install graphframes
# Out:
# Requirement already satisfied: graphframes in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from graphframes) (1.26.4)
# Requirement already satisfied: nose in /usr/local/lib/python3.10/dist-packages (from graphframes) (1.3.7)

# %%
from graphframes import GraphFrame
print("GraphFrames successfully imported!")
# Out:
# GraphFrames successfully imported!

# %%
from auxiliary_files.ConnectedComponents import *
csv = '/content/drive/MyDrive/ADM-HW5/archive_usa_airport/flights_final.csv'

# DATES must be in the format YYYY-MM-DD between 1990 and 2009
start_date = '1990-01-01'
end_date = '2005-12-31'

connections = find_connected_connections(csv, start_date, end_date)
print(connections)
# Out:
# Analyzing flight network from 1990-01-01 to 2005-12-31
# Maximum iterations set to: 10
# Loading and filtering flight network data...
# Total flights in the period: 2699030
# Unique airports: 663
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Converged at iteration 5
# {'number_of_components': 1, 'component_sizes': [663], 'largest_component_size': 663, 'largest_component_airports': ['SEA', 'LMT', 'SFO', 'LAX', 'EAT', 'EKO', 'GTF', 'RBG', 'PIT', 'ORH', 'ITH', 'ORD', 'LAS', 'BGR', 'MSP', 'ABE', 'ACY', 'BGM', 'IAD', 'ROC', 'CAK', 'ROA', 'CID', 'GSP', 'SCE', 'TOL', 'IAH', 'BFF', 'LRD', 'ELP', 'SFB', 'RFD', 'DSM', 'DET', 'EVV', 'MYR', 'SYI', 'MNN', 'LUK', 'MFD', 'GPT', 'ACT', 'YUM', 'RCA', 'FAR', 'LBB', 'MAF', 'HON', 'OPF', 'MPB', 'MIB', 'HIF', 'BMI', 'PIA', 'HUF', 'FOD', 'GNV', 'XNA', 'BMC', 'AHN', 'DBQ', 'PBI', 'ATW', 'PFN', 'EYW', 'BYH', 'CRP', 'EWN', 'AFW', 'EFD', 'TYR', 'APN', 'MMI', 'ESF', 'BPT', 'ORL', 'SWO', 'DRT', 'BDR', 'RDG', 'RUT', 'POB', 'DYS', 'RIV', 'SBY', 'DNN', 'OAJ', 'MRC', 'SCK', 'GUP', 'DRO', 'BZN', 'HVR', 'FSM', 'JNU', 'OKK', 'MZZ', 'MOD', 'VGT', 'WRB', 'SSC', 'AIY', 'ABR', 'CYS', 'HGR', 'GBD', 'DQF', 'NC3', 'HIK', 'EDF', 'LSV', 'DMA', 'BQK', 'LYH', 'HKY', 'ISO', 'PKB', 'VWL', 'DCU', 'MKL', 'ELD', 'AID', 'SIK', 'LBL', 'JBR', 'ZZV', 'STJ', 'STP', 'CPS', 'IRS', 'TDZ', 'TN3', 'BVX', 'THA', 'OH5', 'SBM', 'MTN', 'EAR', 'IDA', 'LCI', 'OLM', 'HII', 'DVT', 'SOW', 'SBP', 'SVH', 'LKE', 'TKF', 'BRL', 'HRO', 'CBM', 'GCC', 'HSI', 'IKK', 'JRB', 'WTC', 'JMS', 'DQU', 'ART', 'WV1', 'LRU', 'TMA', 'SPA', 'OXR', 'SKF', 'LWF', 'MPS', 'MKT', 'HUM', 'LUF', 'RUI', 'HFD', 'FCH', 'RID', 'CBE', 'IRK', 'OH2', 'DQC', 'MUO', 'TDW', 'STK', 'CRE', 'MIQ', 'DNE', 'MDD', 'FAM', 'LAM', 'END', 'DFW', 'ITO', 'OAK', 'STL', 'RNO', 'SMF', 'ABQ', 'FAT', 'SLC', 'SAN', 'PHL', 'EUG', 'YKM', 'ANC', 'LNK', 'MDW', 'CVG', 'AMA', 'BLI', 'MIA', 'MFR', 'BIL', 'DAL', 'MHT', 'BNA', 'TUL', 'SJT', 'SPI', 'GRI', 'CLE', 'LFT', 'FOE', 'DAY', 'SBA', 'GJT', 'JAN', 'MSN', 'ABI', 'BWI', 'SCF', 'CWA', 'KTN', 'RDD', 'BTM', 'JAC', 'DOV', 'LCK', 'HSV', 'FNT', 'LGA', 'AZO', 'CRW', 'BRO', 'BUF', 'ELM', 'PWM', 'CSV', 'RST', 'DLH', 'DPA', 'MCN', 'ILM', 'ABY', 'AVL', 'MGM', 'MDT', 'JHW', 'MCF', 'TUP', 'CLL', 'ALO', 'BIF', 'ADS', 'MHK', 'NIP', 'NBG', 'MXF', 'MIO', 'OGD', 'CPR', 'MDH', 'FYV', 'GCK', 'PDK', 'SGH', 'BFM', 'CLU', 'BYI', 'LAR', 'RKS', 'FMN', 'EAU', 'GGG', 'CDC', 'CVS', 'LAW', 'HOT', 'PNC', 'NZY', 'MKC', 'ILG', 'BMG', 'SQI', 'ADM', 'ATY', 'MVN', 'STC', 'EKA', 'STS', 'VIS', 'JSE', 'SRC', 'DEC', 'IMT', 'STE', 'AOO', 'FTY', 'HVN', 'FEP', 'GAD', 'AGC', 'XXW', 'FDY', 'HLM', 'NQA', 'OFK', 'FBK', 'SER', 'ISN', 'BRD', 'CNM', 'WQM', 'SHD', 'SAF', 'VAD', 'HCA', 'OWB', 'MGW', 'CGI', 'ALM', 'EGP', 'HUT', 'LHV', 'JEF', 'PRB', 'FFO', 'OFF', 'BIH', 'MML', 'AST', 'LUL', 'VWH', 'SAD', 'LWC', 'FFT', 'APC', 'YKN', 'RND', 'OH1', 'CFV', 'FFM', 'CEV', 'MHL', 'PBF', 'FET', 'KY3', 'BFR', 'II2', 'DMO', 'ATO', 'AYS', 'SSI', 'MEJ', 'RDM', 'HLN', 'OMA', 'AUS', 'COS', 'LBF', 'SPS', 'BIS', 'PDX', 'GRB', 'MKE', 'MCW', 'RAP', 'LIT', 'SHV', 'GFK', 'BFL', 'FSD', 'SUX', 'PIR', 'MOT', 'GYY', 'MWH', 'PHX', 'LWS', 'CMI', 'ACV', 'DTW', 'CMH', 'FWA', 'HOU', 'SLN', 'SHR', 'MCE', 'GRK', 'ERI', 'LCH', 'TPA', 'RIC', 'FLL', 'ATL', 'DCA', 'BOS', 'AEX', 'JAX', 'CNW', 'TYS', 'BHM', 'MBS', 'SAV', 'EWR', 'FLG', 'CLT', 'CSG', 'COU', 'HMN', 'BFI', 'YIP', 'IPL', 'CHS', 'SNA', 'BTV', 'AVP', 'PVD', 'BTL', 'LOZ', 'TVC', 'MKG', 'MQT', 'LTS', 'CIC', 'FAI', 'HOB', 'BKX', 'CHA', 'GTR', 'TCL', 'MOB', 'SVN', 'CKB', 'NKX', 'TCM', 'GSB', 'PWK', 'AGS', 'MEI', 'DHN', 'JLN', 'WFB', 'ADQ', 'BWG', 'HKS', 'GMU', 'GDC', 'ANB', 'MIE', 'APF', 'BAD', 'BKW', 'BJI', 'PIB', 'DUC', 'PHT', 'GWO', 'SDM', 'ARA', 'IDI', 'BWD', 'BGS', 'CEC', 'LNS', 'SKA', 'ESC', 'BFD', 'VEL', 'DIK', 'NQX', 'LAL', 'TSS', 'PRC', 'UXJ', 'VLD', 'SGU', 'SZL', 'MYF', 'SAW', 'NPA', 'OGS', 'AXN', 'EKI', 'IN1', 'HUA', 'CVN', 'SVC', 'NEW', 'OH3', 'GFL', 'MCC', 'SKY', 'TSM', 'NJK', 'SEM', 'UKI', 'CVO', 'KDK', 'CWI', 'KY5', 'AUG', 'KY1', 'CGX', 'DLF', 'AMK', 'VWD', 'LJY', 'MRI', 'LSD', 'BOK', 'PSF', 'RBL', 'UCY', 'TVI', 'LXN', 'RMG', 'GRF', 'WVL', 'MOP', 'BBC', 'CAD', 'UBS', 'SME', 'BGD', 'ZXX', 'NGP', 'WDG', 'HYS', 'DDC', 'ICT', 'MCI', 'AOH', 'OKC', 'TNT', 'OCF', 'LEX', 'CAE', 'MSY', 'PVU', 'SJC', 'SBN', 'PIH', 'SAT', 'SLE', 'GEG', 'PUW', 'UCA', ...

# %%
connections
# Out:
# {'number_of_components': 1,
#  'component_sizes': [663],
#  'largest_component_size': 663,
#  'largest_component_airports': ['SEA',
#   'LMT',
#   'SFO',
#   'LAX',
#   'EAT',
#   'EKO',
#   'GTF',
#   'RBG',
#   'PIT',
#   'ORH',
#   'ITH',
#   'ORD',
#   'LAS',
#   'BGR',
#   'MSP',
#   'ABE',
#   'ACY',
#   'BGM',
#   'IAD',
#   'ROC',
#   'CAK',
#   'ROA',
#   'CID',
#   'GSP',
#   'SCE',
#   'TOL',
#   'IAH',
#   'BFF',
#   'LRD',
#   'ELP',
#   'SFB',
#   'RFD',
#   'DSM',
#   'DET',
#   'EVV',
#   'MYR',
#   'SYI',
#   'MNN',
#   'LUK',
#   'MFD',
#   'GPT',
#   'ACT',
#   'YUM',
#   'RCA',
#   'FAR',
#   'LBB',
#   'MAF',
#   'HON',
#   'OPF',
#   'MPB',
#   'MIB',
#   'HIF',
#   'BMI',
#   'PIA',
#   'HUF',
#   'FOD',
#   'GNV',
#   'XNA',
#   'BMC',
#   'AHN',
#   'DBQ',
#   'PBI',
#   'ATW',
#   'PFN',
#   'EYW',
#   'BYH',
#   'CRP',
#   'EWN',
#   'AFW',
#   'EFD',
#   'TYR',
#   'APN',
#   'MMI',
#   'ESF',
#   'BPT',
#   'ORL',
#   'SWO',
#   'DRT',
#   'BDR',
#   'RDG',
#   'RUT',
#   'POB',
#   'DYS',
#   'RIV',
#   'SBY',
#   'DNN',
#   'OAJ',
#   'MRC',
#   'SCK',
#   'GUP',
#   'DRO',
#   'BZN',
#   'HVR',
#   'FSM',
#   'JNU',
#   'OKK',
#   'MZZ',
#   'MOD',
#   'VGT',
#   'WRB',
#   'SSC',
#   'AIY',
#   'ABR',
#   'CYS',
#   'HGR',
#   'GBD',
#   'DQF',
#   'NC3',
#   'HIK',
#   'EDF',
#   'LSV',
#   'DMA',
#   'BQK',
#   'LYH',
#   'HKY',
#   'ISO',
#   'PKB',
#   'VWL',
#   'DCU',
#   'MKL',
#   'ELD',
#   'AID',
#   'SIK',
#   'LBL',
#   'JBR',
#   'ZZV',
#   'STJ',
#   'STP',
#   'CPS',
#   'IRS',
#   'TDZ',
#   'TN3',
#   'BVX',
#   'THA',
#   'OH5',
#   'SBM',
#   'MTN',
#   'EAR',
#   'IDA',
#   'LCI',
#   'OLM',
#   'HII',
#   'DVT',
#   'SOW',
#   'SBP',
#   'SVH',
#   'LKE',
#   'TKF',
#   'BRL',
#   'HRO',
#   'CBM',
#   'GCC',
#   'HSI',
#   'IKK',
#   'JRB',
#   'WTC',
#   'JMS',
#   'DQU',
#   'ART',
#   'WV1',
#   'LRU',
#   'TMA',
#   'SPA',
#   'OXR',
#   'SKF',
#   'LWF',
#   'MPS',
#   'MKT',
#   'HUM',
#   'LUF',
#   'RUI',
#   'HFD',
#   'FCH',
#   'RID',
#   'CBE',
#   'IRK',
#   'OH2',
#   'DQC',
#   'MUO',
#   'TDW',
#   'STK',
#   'CRE',
#   'MIQ',
#   'DNE',
#   'MDD',
#   'FAM',
#   'LAM',
#   'END',
#   'DFW',
#   'ITO',
#   'OAK',
#   'STL',
#   'RNO',
#   'SMF',
#   'ABQ',
#   'FAT',
#   'SLC',
#   'SAN',
#   'PHL',
#   'EUG',
#   'YKM',
#   'ANC',
#   'LNK',
#   'MDW',
#   'CVG',
#   'AMA',
#   'BLI',
#   'MIA',
#   'MFR',
#   'BIL',
#   'DAL',
#   'MHT',
#   'BNA',
#   'TUL',
#   'SJT',
#   'SPI',
#   'GRI',
#   'CLE',
#   'LFT',
#   'FOE',
#   'DAY',
#   'SBA',
#   'GJT',
#   'JAN',
#   'MSN',
#   'ABI',
#   'BWI',
#   'SCF',
#   'CWA',
#   'KTN',
#   'RDD',
#   'BTM',
#   'JAC',
#   'DOV',
#   'LCK',
#   'HSV',
#   'FNT',
#   'LGA',
#   'AZO',
#   'CRW',
#   'BRO',
#   'BUF',
#   'ELM',
#   'PWM',
#   'CSV',
#   'RST',
#   'DLH',
#   'DPA',
#   'MCN',
#   'ILM',
#   'ABY',
#   'AVL',
#   'MGM',
#   'MDT',
#   'JHW',
#   'MCF',
#   'TUP',
#   'CLL',
#   'ALO',
#   'BIF',
#   'ADS',
#   'MHK',
#   'NIP',
#   'NBG',
#   'MXF',
#   'MIO',
#   'OGD',
#   'CPR',
#   'MDH',
#   'FYV',
#   'GCK',
#   'PDK',
#   'SGH',
#   'BFM',
#   'CLU',
#   'BYI',
#   'LAR',
#   'RKS',
#   'FMN',
#   'EAU',
#   'GGG',
#   'CDC',
#   'CVS',
#   'LAW',
#   'HOT',
#   'PNC',
#   'NZY',
#   'MKC',
#   'ILG',
#   'BMG',
#   'SQI',
#   'ADM',
#   'ATY',
#   'MVN',
#   'STC',
#   'EKA',
#   'STS',
#   'VIS',
#   'JSE',
#   'SRC',
#   'DEC',
#   'IMT',
#   'STE',
#   'AOO',
#   'FTY',
#   'HVN',
#   'FEP',
#   'GAD',
#   'AGC',
#   'XXW',
#   'FDY',
#   'HLM',
#   'NQA',
#   'OFK',
#   'FBK',
#   'SER',
#   'ISN',
#   'BRD',
#   'CNM',
#   'WQM',
#   'SHD',
#   'SAF',
#   'VAD',
#   'HCA',
#   'OWB',
#   'MGW',
#   'CGI',
#   'ALM',
#   'EGP',
#   'HUT',
#   'LHV',
#   'JEF',
#   'PRB',
#   'FFO',
#   'OFF',
#   'BIH',
#   'MML',
#   'AST',
#   'LUL',
#   'VWH',
#   'SAD',
#   'LWC',
#   'FFT',
#   'APC',
#   'YKN',
#   'RND',
#   'OH1',
#   'CFV',
#   'FFM',
#   'CEV',
#   'MHL',
#   'PBF',
#   'FET',
#   'KY3',
#   'BFR',
#   'II2',
#   'DMO',
#   'ATO',
#   'AYS',
#   'SSI',
#   'MEJ',
#   'RDM',
#   'HLN',
#   'OMA',
#   'AUS',
#   'COS',
#   'LBF',
#   'SPS',
#   'BIS',
#   'PDX',
#   'GRB',
#   'MKE',
#   'MCW',
#   'RAP',
#   'LIT',
#   'SHV',
#   'GFK',
#   'BFL',
#   'FSD',
#   'SUX',
#   'PIR',
#   'MOT',
#   'GYY',
#   'MWH',
#   'PHX',
#   'LWS',
#   'CMI',
#   'ACV',
#   'DTW',
#   'CMH',
#   'FWA',
#   'HOU',
#   'SLN',
#   'SHR',
#   'MCE',
#   'GRK',
#   'ERI',
#   'LCH',
#   'TPA',
#   'RIC',
#   'FLL',
#   'ATL',
#   'DCA',
#   'BOS',
#   'AEX',
#   'JAX',
#   'CNW',
#   'TYS',
#   'BHM',
#   'MBS',
#   'SAV',
#   'EWR',
#   'FLG',
#   'CLT',
#   'CSG',
#   'COU',
#   'HMN',
#   'BFI',
#   'YIP',
#   'IPL',
#   'CHS',
#   'SNA',
#   'BTV',
#   'AVP',
#   'PVD',
#   'BTL',
#   'LOZ',
#   'TVC',
#   'MKG',
#   'MQT',
#   'LTS',
#   'CIC',
#   'FAI',
#   'HOB',
#   'BKX',
#   'CHA',
#   'GTR',
#   'TCL',
#   'MOB',
#   'SVN',
#   'CKB',
#   'NKX',
#   'TCM',
#   'GSB',
#   'PWK',
#   'AGS',
#   'MEI',
#   'DHN',
#   'JLN',
#   'WFB',
#   'ADQ',
#   'BWG',
#   'HKS',
#   'GMU',
#   'GDC',
#   'ANB',
#   'MIE',
#   'APF',
#   'BAD',
#   'BKW',
#   'BJI',
#   'PIB',
#   'DUC',
#   'PHT',
#   'GWO',
#   'SDM',
#   'ARA',
#   'IDI',
#   'BWD',
#   'BGS',
#   'CEC',
#   'LNS',
#   'SKA',
#   'ESC',
#   'BFD',
#   'VEL',
#   'DIK',
#   'NQX',
#   'LAL',
#   'TSS',
#   'PRC',
#   'UXJ',
#   'VLD',
#   'SGU',
#   'SZL',
#   'MYF',
#   'SAW',
#   'NPA',
#   'OGS',
#   'AXN',
#   'EKI',
#   'IN1',
#   'HUA',
#   'CVN',
#   'SVC',
#   'NEW',
#   'OH3',
#   'GFL',
#   'MCC',
#   'SKY',
#   'TSM',
#   'NJK',
#   'SEM',
#   'UKI',
#   'CVO',
#   'KDK',
#   'CWI',
#   'KY5',
#   'AUG',
#   'KY1',
#   'CGX',
#   'DLF',
#   'AMK',
#   'VWD',
#   'LJY',
#   'MRI',
#   'LSD',
#   'BOK',
#   'PSF',
#   'RBL',
#   'UCY',
#   'TVI',
#   'LXN',
#   'RMG',
#   'GRF',
#   'WVL',
#   'MOP',
#   'BBC',
#   'CAD',
#   'UBS',
#   'SME',
#   'BGD',
#   'ZXX',
#   'NGP',
#   'WDG',
#   'HYS',
#   'DDC',
#   'ICT',
#   'MCI',
#   'AOH',
#   'OKC',
#   'TNT',
#   'OCF',
#   'LEX',
#   'CAE',
#   'MSY',
#   'PVU',
#   'SJC',
#   'SBN',
#   'PIH',
#   'SAT',
#   'SLE',
#   'GEG',
#   'PUW',
#   'UCA',
#   'SYR',
#   'ALB',
#   'YNG',
#   'MEM',
#   'MCO',
#   'BDL',
#   'JFK',
#   'RDU',
#   'IND',
#   'GRR',
#   'GSO',
#   'LAN',
#   'SGF',
#   'ILN',
#   'JST',
#   'CHO',
#   'FTW',
#   'SUS',
#   'PGV',
#   'TUS',
#   'PUB',
#   'MGY',
#   'LAF',
#   'MWA',
#   'PAH',
#   'TBN',
#   'MLU',
#   'PNS',
#   'BTR',
#   'GLH',
#   'FLO',
#   'ALW',
#   'UIN',
#   'BSM',
#   'FCA',
#   'LSF',
#   'OLS',
#   'FWH',
#   'TIK',
#   'MSO',
#   'AWX',
#   'HNL',
#   'JXN',
#   'OGG',
#   'ILE',
#   'VCT',
#   'WGO',
#   'IPT',
#   'RWI',
#   'FAY',
#   'TLH',
#   'MOR',
#   'TTN',
#   'PAM',
#   'BKL',
#   'OSH',
#   'TWF',
#   'AND',
#   'ROW',
#   'EIL',
#   'MHR',
#   'SHN',
#   'CLM',
#   'LGD',
#   'PDT',
#   'SFF',
#   'PNE',
#   'LSE',
#   'RKD',
#   'MTJ',
#   'JRA',
#   'TBR',
#   'EKX',
#   'ASN',
#   'HBG',
#   'ELN',
#   'ODW',
#   'OGB',
#   'SUM',
#   'AXV',
#   'GVL',
#   'GCY',
#   'NZC',
#   'MVW',
#   'PWA',
#   'NFL',
#   'BJJ',
#   'MS1',
#   'DNV',
#   'ISM',
#   'IAB',
#   'RIW',
#   'GBG',
#   'GRD',
#   'SLB',
#   'MUT',
#   'LFK',
#   'MIW',
#   'FXE',
#   'PUC',
#   'CRS',
#   'FVS',
#   'SNS',
#   'XWL',
#   'RVS',
#   'GLW',
#   'PMH',
#   'NZJ']}

# %% [markdown]
# with graph frame

# %%
from graphframes import GraphFrame

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from graphframes import GraphFrame
import time

def find_connected_connections_graph(csv_path: str, start_date: str, end_date: str) -> dict:

    start_time = time.time()


    spark = SparkSession.builder \
        .appName("GraphFramesExample") \
        .config("spark.jars.packages", "graphframes:graphframes:0.8.2-spark3.1-s_2.12") \
        .getOrCreate()


    spark.sparkContext.setCheckpointDir("/tmp/checkpoints")

    print(f"Analyzing flight network from {start_date} to {end_date}")


    print("Loading and filtering flight network data...")
    df = spark.read.csv(csv_path, header=True, inferSchema=True)


    df = df.withColumn("Fly_date", col("Fly_date").cast("date"))
    df = df.filter((col("Fly_date") >= start_date) & (col("Fly_date") <= end_date))
    df = df.select("Origin_airport", "Destination_airport", "Fly_date")


    unique_airports = df.select("Origin_airport").distinct().union(df.select("Destination_airport").distinct()).distinct()



    vertices = unique_airports.withColumnRenamed("Origin_airport", "id")
    edges = df.withColumnRenamed("Origin_airport", "src").withColumnRenamed("Destination_airport", "dst")


    g = GraphFrame(vertices, edges)


    print("Finding connected components...")
    result = g.connectedComponents()


    component_sizes = result.groupBy("component").count().collect()
    sizes = [row["count"] for row in component_sizes]


    largest_component_id = max(component_sizes, key=lambda x: x["count"])["component"]
    largest_component = result.filter(result.component == largest_component_id).select("id").rdd.map(lambda x: x[0]).collect()


    execution_time = time.time() - start_time


    final_result = {
        'number_of_components': len(component_sizes),
        'component_sizes': sizes,
        'largest_component_size': max(sizes),
        'largest_component_airports': largest_component,
        'execution_time': execution_time
    }


    spark.stop()

    return final_result

# %%
from auxiliary_files.ConnectedComponents import *
csv = '/content/drive/MyDrive/ADM-HW5/archive_usa_airport/flights_final.csv'

# DATES must be in the format YYYY-MM-DD between 1990 and 2009
start_date = '1990-01-01'
end_date = '2005-12-31'
connections_GraphFrame = find_connected_connections_graph(csv, start_date, end_date)
print(connections_GraphFrame)
# Out:
# Analyzing flight network from 1990-01-01 to 2005-12-31
# Loading and filtering flight network data...
# Finding connected components...
# {'number_of_components': 1, 'component_sizes': [663], 'largest_component_size': 663, 'largest_component_airports': ['BGM', 'CRS', 'VWD', 'MOR', 'MSY', 'RDG', 'GEG', 'DRT', 'HVR', 'MML', 'SNA', 'CGX', 'GTF', 'GRB', 'FOD', 'OPF', 'JRB', 'BVX', 'UBS', 'IDA', 'MDD', 'STE', 'GRR', 'UKI', 'PVU', 'MPB', 'JLN', 'EUG', 'ARA', 'TSM', 'GYY', 'RIV', 'ATY', 'GSO', 'PVD', 'MYR', 'CNW', 'ISO', 'GMU', 'OAK', 'CEV', 'EAR', 'BTM', 'MSN', 'FAR', 'FSM', 'MQT', 'END', 'YKN', 'AIY', 'RCA', 'RKD', 'TBR', 'DET', 'OCF', 'HUF', 'SQI', 'ESC', 'GWO', 'LAL', 'FXE', 'FET', 'SNS', 'RFD', 'DCA', 'JEF', 'GSB', 'MFD', 'AXN', 'LWS', 'CID', 'MLU', 'SWO', 'GTR', 'PIB', 'OLM', 'DCU', 'MDH', 'HLN', 'GUP', 'XXW', 'SVC', 'ISM', 'DNE', 'JBR', 'DDC', 'CSV', 'FVS', 'PNC', 'EIL', 'RDM', 'LEX', 'FLO', 'BRL', 'IDI', 'OGB', 'JMS', 'AOH', 'OH2', 'SCE', 'SBY', 'HOT', 'MYF', 'MZZ', 'AMK', 'EVV', 'KTN', 'AFW', 'IRK', 'FTW', 'SIK', 'CWA', 'CRW', 'OGS', 'FDY', 'VCT', 'PSF', 'GCK', 'SAV', 'SHN', 'TCM', 'LSD', 'MIW', 'MNN', 'MIO', 'EGP', 'MOD', 'CMH', 'YNG', 'DUC', 'MVN', 'MWH', 'LBF', 'FFO', 'MKL', 'AYS', 'NZJ', 'AST', 'CAK', 'YIP', 'TYR', 'UCA', 'CHO', 'HSI', 'MOB', 'LSF', 'FFM', 'PNS', 'MCN', 'DIK', 'SPA', 'GFL', 'CEC', 'IN1', 'IAH', 'FMN', 'PHT', 'BKW', 'SLN', 'HNL', 'SAW', 'SHV', 'ERI', 'SJC', 'CVG', 'TOL', 'SDM', 'GBG', 'RND', 'BUF', 'LGA', 'TLH', 'BSM', 'GCY', 'FAM', 'CDC', 'ACT', 'BTL', 'GVL', 'RDD', 'TBN', 'TN3', 'AUS', 'GCC', 'HMN', 'MIB', 'AHN', 'MCC', 'CAD', 'ATW', 'DHN', 'GAD', 'OFK', 'WVL', 'GJT', 'AVL', 'LYH', 'FYV', 'ADM', 'II2', 'LKE', 'GFK', 'BFL', 'RIW', 'DMA', 'BGD', 'GRF', 'RNO', 'SBN', 'GDC', 'EYW', 'NZY', 'BJI', 'TTN', 'MMI', 'DMO', 'OH5', 'OFF', 'RST', 'JAC', 'DNV', 'CHS', 'HGR', 'LWF', 'TUL', 'IPL', 'POB', 'HUM', 'STP', 'VWL', 'AMA', 'PBF', 'RID', 'DVT', 'PDT', 'ASN', 'MRC', 'MKC', 'FWH', 'OH1', 'CFV', 'PUW', 'BOS', 'SSC', 'UCY', 'APC', 'MAF', 'TUP', 'MRI', 'EWR', 'THA', 'PWK', 'BFR', 'OKK', 'RBG', 'LOZ', 'NPA', 'JSE', 'BIS', 'LAS', 'OGD', 'EDF', 'SZL', 'FTY', 'JAN', 'FAI', 'ITO', 'TDW', 'UIN', 'ILN', 'BMC', 'IMT', 'MVW', 'XNA', 'DLH', 'BWD', 'DPA', 'SOW', 'SME', 'WQM', 'BKL', 'CVO', 'EWN', 'FBK', 'PDK', 'SGU', 'CPR', 'ALB', 'DQF', 'NEW', 'BDR', 'LNK', 'GRI', 'SBA', 'IAD', 'CVN', 'HOB', 'MEI', 'LAR', 'BGS', 'BJJ', 'LGD', 'CLM', 'BRD', 'BRO', 'DRO', 'WFB', 'LWC', 'TMA', 'BMI', 'RKS', 'ELD', 'IAB', 'SEA', 'GLW', 'CMI', 'LAN', 'NQA', 'LNS', 'VEL', 'BIH', 'LRD', 'WDG', 'EKI', 'VLD', 'MCF', 'HYS', 'BFI', 'MCI', 'PIR', 'BWG', 'DLF', 'FLG', 'AND', 'DQC', 'HUA', 'GRK', 'CRE', 'BNA', 'CLL', 'CLT', 'TVC', 'CGI', 'BLI', 'ADS', 'WGO', 'CIC', 'HUT', 'ORH', 'GBD', 'NC3', 'ABQ', 'PBI', 'RMG', 'ART', 'TKF', 'ACV', 'SCK', 'LAW', 'SLE', 'MUO', 'IKK', 'ITH', 'BDL', 'DAL', 'DBQ', 'AUG', 'LCI', 'RBL', 'CLE', 'APF', 'BFD', 'PDX', 'ATO', 'LXN', 'MFR', 'TWF', 'MIA', 'ILG', 'STJ', 'BWI', 'TPA', 'APN', 'PRC', 'OKC', 'ROA', 'RWI', 'XWL', 'SMF', 'SPI', 'MIE', 'SFB', 'SAD', 'ELN', 'BFF', 'ABI', 'OXR', 'ODW', 'HFD', 'ELM', 'MBS', 'HKS', 'HIF', 'SER', 'DNN', 'MPS', 'PHX', 'ABR', 'FCA', 'IRS', 'STL', 'PWM', 'ABY', 'MXF', 'DFW', 'ABE', 'MHT', 'KY5', 'LAF', 'VIS', 'MTN', 'SSI', 'LSE', 'GSP', 'PAM', 'BFM', 'HLM', 'SFF', 'FAY', 'EFD', 'MKT', 'LMT', 'MIQ', 'EKO', 'LBB', 'HRO', 'SYI', 'BMG', 'BKX', 'BIF', 'CBM', 'CRP', 'LUK', 'PWA', 'EAT', 'KDK', 'DYS', 'HVN', 'TIK', 'FSD', 'AGC', 'ZZV', 'CSG', 'BQK', 'SFO', 'MGY', 'STK', 'MEJ', 'MEM', 'SAF', 'KY3', 'MHL', 'JHW', 'ELP', 'SKF', 'NIP', 'PUC', 'CNM', 'SUM', 'HBG', 'BHM', 'PNE', 'JRA', 'PMH', 'YKM', 'FLL', 'PIH', 'ATL', 'FNT', 'HII', 'AOO', 'TVI', 'MCW', 'DEC', 'RIC', 'NJK', 'ANB', 'LJY', 'LCK', 'MUT', 'DAY', 'CWI', 'OMA', 'EKA', 'SJT', 'LRU', 'WTC', 'LCH', 'MOP', 'STC', 'BPT', 'MHK', 'SEM', 'ALM', 'LHV', 'MWA', 'LTS', 'LIT', 'NZC', 'SGH', 'DQU', 'FAT', 'ICT', 'CAE', 'EKX', 'SVH', 'PFN', 'SLB', 'ORD', 'AVP', 'LBL', 'PRB', 'BTV', 'NFL', 'COU', 'MKG', 'PKB', 'IPT', 'FEP', 'MGW', 'BIL', 'SPS', 'ESF', 'AEX', 'PUB', 'ILM', 'VAD', 'FCH', 'PIA', 'SVN', 'OLS', 'RDU', 'UXJ', 'NGP', 'PGV', 'LUF', 'GRD', 'MKE', 'LSV', 'SKA', 'SYR', 'ISN', 'AXV', 'VGT', 'HSV', ...

# %%
import time
from typing import Dict, Any
from dataclasses import dataclass
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from graphframes import GraphFrame

@dataclass
class TimingMetrics:
    setup_time: float = 0
    data_loading_time: float = 0
    processing_time: float = 0
    component_analysis_time: float = 0
    total_time: float = 0

def measure_time(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        return result, end_time - start_time
    return wrapper

def find_connected_connections_with_timing(csv_path: str, start_date: str, end_date: str) -> Dict[str, Any]:
    metrics = TimingMetrics()
    total_start = time.time()

    # Setup timing
    setup_start = time.time()
    spark = SparkSession.builder.appName("ConnectedComponents").getOrCreate()
    metrics.setup_time = time.time() - setup_start

    # Data loading timing
    loading_start = time.time()
    df = spark.read.csv(csv_path, header=True)
    df = df.filter((df.Fly_date >= start_date) & (df.Fly_date <= end_date))
    df = df.select("Origin_airport", "Destination_airport", "Fly_date")
    metrics.data_loading_time = time.time() - loading_start

    # Processing timing
    processing_start = time.time()

    def emit_bidirectional_edges(row):
        origin = row.Origin_airport
        dest = row.Destination_airport
        return [(origin, dest), (dest, origin)]


    edges_rdd = df.rdd.flatMap(emit_bidirectional_edges).distinct()


    def update_components(edges):
        components = {}

        def find(node):
            if node not in components:
                components[node] = node
            if components[node] != node:
                components[node] = find(components[node])
            return components[node]

        def union(node1, node2):
            root1, root2 = find(node1), find(node2)
            if root1 != root2:
                components[root2] = root1


        for origin, dest in edges:
            union(origin, dest)


        return [(node, find(node)) for node in components.keys()]


    components_rdd = edges_rdd.mapPartitions(lambda x: update_components(x))


    prev_components = None
    curr_components = components_rdd.collectAsMap()

    iteration = 1
    while prev_components != curr_components and iteration <= 10:
        print(f"Iteration {iteration}")
        prev_components = curr_components
        components_rdd = edges_rdd.map(
            lambda edge: (edge[1], curr_components.get(edge[0]))
        ).filter(
            lambda x: x[1] is not None
        ).reduceByKey(
            lambda x, y: min(x, y)
        )

        curr_components = components_rdd.collectAsMap()
        iteration += 1


    if prev_components == curr_components:
        print(f"Converged at iteration {iteration - 1}")
    else:
        print("Reached maximum iterations without convergence.")



    metrics.processing_time = time.time() - processing_start

    # Component analysis timing
    analysis_start = time.time()
    final_components_df = spark.createDataFrame(
        components_rdd.map(lambda x: (x[0], x[1])).collect(),
        ["node", "component_id"]
    )

    component_sizes = final_components_df.groupBy("component_id").count().collect()
    sizes = [row["count"] for row in component_sizes]

    largest_component_id = max(component_sizes, key=lambda x: x["count"])["component_id"]
    largest_component = final_components_df.filter(
        final_components_df.component_id == largest_component_id
    ).select("node").rdd.map(lambda x: x[0]).collect()
    metrics.component_analysis_time = time.time() - analysis_start

    metrics.total_time = time.time() - total_start

    result = {
        'number_of_components': len(component_sizes),
        'component_sizes': sizes,
        'largest_component_size': max(sizes),
        'largest_component_airports': largest_component,
        'timing_metrics': {
            'setup_time': metrics.setup_time,
            'data_loading_time': metrics.data_loading_time,
            'processing_time': metrics.processing_time,
            'component_analysis_time': metrics.component_analysis_time,
            'total_time': metrics.total_time
        }
    }

    spark.stop()
    return result

def find_connected_connections_graph_with_timing(csv_path: str, start_date: str, end_date: str) -> Dict[str, Any]:
    metrics = TimingMetrics()
    total_start = time.time()

    # Setup timing
    setup_start = time.time()
    spark = SparkSession.builder \
        .appName("GraphFramesExample") \
        .config("spark.jars.packages", "graphframes:graphframes:0.8.2-spark3.1-s_2.12") \
        .getOrCreate()
    spark.sparkContext.setCheckpointDir("/tmp/checkpoints")
    metrics.setup_time = time.time() - setup_start

    # Data loading timing
    loading_start = time.time()
    df = spark.read.csv(csv_path, header=True, inferSchema=True)
    df = df.withColumn("Fly_date", col("Fly_date").cast("date"))
    df = df.filter((col("Fly_date") >= start_date) & (col("Fly_date") <= end_date))
    df = df.select("Origin_airport", "Destination_airport", "Fly_date")
    metrics.data_loading_time = time.time() - loading_start

    # Processing timing
    processing_start = time.time()
    vertices = df.select("Origin_airport").distinct().union(
        df.select("Destination_airport").distinct()
    ).distinct().withColumnRenamed("Origin_airport", "id")

    edges = df.withColumnRenamed("Origin_airport", "src") \
              .withColumnRenamed("Destination_airport", "dst")

    g = GraphFrame(vertices, edges)
    result = g.connectedComponents()
    metrics.processing_time = time.time() - processing_start

    # Component analysis timing
    analysis_start = time.time()
    component_sizes = result.groupBy("component").count().collect()
    sizes = [row["count"] for row in component_sizes]

    largest_component_id = max(component_sizes, key=lambda x: x["count"])["component"]
    largest_component = result.filter(result.component == largest_component_id) \
                            .select("id").rdd.map(lambda x: x[0]).collect()
    metrics.component_analysis_time = time.time() - analysis_start

    metrics.total_time = time.time() - total_start

    final_result = {
        'number_of_components': len(component_sizes),
        'component_sizes': sizes,
        'largest_component_size': max(sizes),
        'largest_component_airports': largest_component,
        'timing_metrics': {
            'setup_time': metrics.setup_time,
            'data_loading_time': metrics.data_loading_time,
            'processing_time': metrics.processing_time,
            'component_analysis_time': metrics.component_analysis_time,
            'total_time': metrics.total_time
        }
    }

    spark.stop()
    return final_result

def compare_implementations_with_timing(csv_path: str, start_date: str, end_date: str):
    print("Running Original Implementation...")
    original_result = find_connected_connections_with_timing(csv_path, start_date, end_date)

    print("\nRunning GraphFrames Implementation...")
    graphframes_result = find_connected_connections_graph_with_timing(csv_path, start_date, end_date)

    print("\nTiming Analysis:")
    print("-" * 80)
    print(f"{'Section':<25} {'Original (s)':<15} {'GraphFrames (s)':<15} {'Difference (s)':<15}")
    print("-" * 80)

    sections = ['setup_time', 'data_loading_time', 'processing_time', 'component_analysis_time', 'total_time']

    for section in sections:
        orig_time = original_result['timing_metrics'][section]
        graph_time = graphframes_result['timing_metrics'][section]
        diff = orig_time - graph_time
        print(f"{section:<25} {orig_time:>14.2f} {graph_time:>14.2f} {diff:>14.2f}")

    return original_result, graphframes_result

csv_path = '/content/drive/MyDrive/ADM-HW5/archive_usa_airport/flights_final.csv'
start_date = '1990-01-01'
end_date = '2005-12-31'

original_result, graphframes_result = compare_implementations_with_timing(csv_path, start_date, end_date)
# Out:
# Running Original Implementation...
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Converged at iteration 5
#
# Running GraphFrames Implementation...
#
# Timing Analysis:
# --------------------------------------------------------------------------------
# Section                   Original (s)    GraphFrames (s) Difference (s)
# --------------------------------------------------------------------------------
# setup_time                          0.19           0.33          -0.14
# data_loading_time                   0.22           9.91          -9.69
# processing_time                    40.64         126.53         -85.88
# component_analysis_time             2.15          52.54         -50.39
# total_time                         43.19         189.30        -146.11
